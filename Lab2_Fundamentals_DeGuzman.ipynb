# %%
ENGINEER = "De Guzman"
STUDENT_ID = "TUPM-25-0030"
SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithm Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: De Guzman
# Algorithm Seed Value: 0

# %%
actual = 0.1 + 0.2
print(f"Python store: {actual}")
if actual == 0.3:
    print("Result: Perfect Match")
else:
    print("Result: PRECISION ERROR (Binary Artifact)")
# Out:
# Python store: 0.30000000000000004
# Result: PRECISION ERROR (Binary Artifact)

# %%
first_letter = ENGINEER[0]
byte_val = ord(first_letter)

print(f"Character: {first_letter}")
print(f"ASCII Value: {byte_val}")
print(f"Next in Sequence: {chr(byte_val + 1)}")
# Out:
# Character: D
# ASCII Value: 68
# Next in Sequence: E

# %%
raw_in = input("Enter Name (add messy spaces):")
clean_in = raw_in.strip().upper()
print(f"Original: '{raw_in}' | Cleaned: '{clean_in}'")
# Out:
# Original: 'de guzman' | Cleaned: 'DE GUZMAN'

# %%
user_input = input("Press Enter (leave empty) or type data:")
if user_input:
    print(f"Data Detected: {user_input}")
else:
    print("ALERT: No data stream detected")
# Out:
# Data Detected: 777

# %%
campus = STUDENT_ID[0:4]
unique_id = STUDENT_ID[8:]

tokens = STUDENT_ID.split("-")


print(f"Campus Code: {campus}")
print(f"Unique Sequence: {unique_id}")
print(f"Token List: {tokens}")
# Out:
# Campus Code: TUPM
# Unique Sequence: 0030
# Token List: ['TUPM', '25', '0030']

# %%
if SEED_NUM % 2 == 0:
    priority = "LOW (Even Seed)"
else:
    priority = "HIGH (Odd Seed)"

print(f"System Priority: {priority}")
# Out:
# System Priority: LOW (Even Seed)

# %%
limit = (SEED_NUM * 10) + 20
print(f"---SAFETY LIMIT: {limit}---")

val = int(input("Enter Sensor Reading: "))

if val > limit:
    print(("ALERT: Over Limit"))
elif val < 5:
    print("ALERT: Low Signal")
else:
    print("STATUS: Nominal")
# Out:
# ---SAFETY LIMIT: 20---
# STATUS: Nominal

# %%
try:
    voltage = int(input("Enter Voltage (Numeric): "))
    print(f"Voltage Captured: {voltage}V")
except:
    print("SYSTEM ERROR: Input must be numeric. Resetting to 0")
    voltage = 0
print(f"System Continues... Current Voltage: {voltage}V")
# Out:
# SYSTEM ERROR: Input must be numeric. Resetting to 0
# System Continues... Current Voltage: 0V

# %%
has_power = False
if has_power and (10 / 0 == 0):
    print("System On")
else:
    print("System Off (Short-Circuit Triggered)")
# Out:
# System Off (Short-Circuit Triggered)

# %%
loops = SEED_NUM + 3
print(f"---RUNNING {loops} CYCLES ---")
for i in range(1, loops + 1):
    print(f"Cycle {i}/{loops} ... Complete")
# Out:
# ---RUNNING 3 CYCLES ---
# Cycle 1/3 ... Complete
# Cycle 2/3 ... Complete
# Cycle 3/3 ... Complete

# %%
tokens = [None, None, "513"]
rows = int(tokens[2][0])
cols = int(tokens[2][-1])
print(f"Generating {rows}x{cols} Matrix:")
for r in range(rows):
    for c in range(cols):
        print("#", end=" ")
    print()
print(rows)
print(cols)
# Out:
# Generating 5x3 Matrix:
# # # #
# # # #
# # # #
# # # #
# # # #
# 5
# 3

# %%
while True:
    pwd = input("type 'ADMIN' to exit:")
    if pwd == "ADMIN":
        print("Unlocked.")
        break
    else:
        print("Access Denied.")
# Out:
# Unlocked.

# %%
A = byte_val
B = SEED_NUM
C = loops
verification_hash = (A * B) - C
print(f"User: {ENGINEER}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# User: De Guzman
# Forensic Signature: -3

# %%
ENGINEER = "DE GUZMAN" # Your Surname
STUDENT_ID = "TUPM-25-0030" # Your ID
SEED_NUM = int(STUDENT_ID[-1])  # Calculate seed again (e.g., 4)
# --- NOW THE EXERCISE CODE WILL WORK ---

target_name = ENGINEER
redacted_name = ""

print(f"Original Surname: {target_name}")

for char in target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

print(f"Redacted Output: {redacted_name}")
# Out:
# Original Surname: DE GUZMAN
# Redacted Output: D0 G0ZM0N

# %%
# [APPENDIX EXERCISE 2] FORENSIC SIGNATURE

# --- RE-INITIALIZE DATA (Because this is a new file) ---
ENGINEER = "ABDALLAH"     # Replace with your Surname
STUDENT_ID = "TUPM-24-1234" # Replace with your ID
SEED_NUM = int(STUDENT_ID[-1])
# -------------------------------------------------------

# 1. Get the first letter's ASCII value
first_letter = ENGINEER[0]
ascii_val = ord(first_letter)

# 2. detailed in Task 14, loops was SEED_NUM + 3
total_loops = SEED_NUM + 3

# 3. Calculate the Verification Hash
# Formula: (ASCII * SEED) - LOOPS
verification_hash = (ascii_val * SEED_NUM) - total_loops

print("--- ASSESSMENT DATA FOR EXERCISE 2 ---")
print(f"First Letter ASCII (A): {ascii_val}")
print(f"SEED_NUM (B): {SEED_NUM}")
print(f"Total Loops (C): {total_loops}")
print(f"Verification Hash: {verification_hash}")
# Out:
# --- ASSESSMENT DATA FOR EXERCISE 2 ---
# First Letter ASCII (A): 65
# SEED_NUM (B): 4
# Total Loops (C): 7
# Verification Hash: 253

# %%
# [APPENDIX EXERCISE 3] SECURE SYSTEM GATE

correct_password = "TUPM-25-0030"  # Set your password here
attempts = 0

print("--- SYSTEM LOCKED ---")

while True:
    # 1. Ask user for input
    user_pass = input("Enter Password: ")
    attempts += 1
    
    # 2. Check if password matches
    if user_pass == correct_password:
        print(f"\n>> ACCESS GRANTED. Welcome, {ENGINEER}.")
        print(f">> Total Attempts Before Success: {attempts}")
        break  # This stops the infinite loop
    else:
        print(">> Access Denied. Try again.")

# Output for your Manual
print("\n--- ASSESSMENT DATA FOR EXERCISE 3 ---")
print(f"Correct Password Set: {correct_password}")
print(f"Attempts Before Success: {attempts}")
# Out:
# --- SYSTEM LOCKED ---
# >> Access Denied. Try again.
# >> Access Denied. Try again.
#
# >> ACCESS GRANTED. Welcome, ABDALLAH.
# >> Total Attempts Before Success: 3
#
# --- ASSESSMENT DATA FOR EXERCISE 3 ---
# Correct Password Set: TUPM-25-0030
# Attempts Before Success: 3
